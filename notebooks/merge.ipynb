# %%
import pandas as pd
import os
import numpy as np

# %%
features_df = pd.read_csv("Code\\NEW\\features.csv", index_col = 0)

# %%
scores_df = pd.read_csv("Code\\NEW\\balanced_dataset_details_7thSept.csv", index_col = 0)

# %%
df_score_name = set(scores_df['Video Name'])
df_features_name = set(features_df['Video Name'])

# %%
for video in df_features_name:
    if video not in df_score_name:
        print(video)

# %%
scores_df.sort_values(by=["Video Name"])
features_df.sort_values(by=["Video Name"])
# Out:
#            Video Name  Average Brightness  Average Contrast  \
# 0        P01_01_1.mp4          135.500049          0.340637
# 1      P01_01_102.mp4          162.289770          0.354829
# 2      P01_01_103.mp4           99.984907          0.330643
# 3      P01_01_109.mp4          186.054577          0.316723
# 4      P01_01_115.mp4          178.583482          0.375943
# ...               ...                 ...               ...
# 16795  P37_103_59.mp4           84.305491          0.413508
# 16796  P37_103_63.mp4           96.443705          0.375974
# 16797  P37_103_71.mp4           76.634427          0.619754
# 16798  P37_103_73.mp4           58.953690          0.592401
# 16799   P37_103_9.mp4          141.773189          0.556712
#
#        Average Spatial Noise  Average Temporal Noise  \
# 0                      0.613                8.456470
# 1                      3.020               23.252530
# 2                      0.993                9.638859
# ...

# %%
part_scores_df = scores_df[['Video Name', 'Quality Score']]

# %%
merged_df = pd.merge(features_df, part_scores_df, how='left')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16800 entries, 0 to 16799
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Video Name                  16800 non-null  object
#  1   Average Brightness          16800 non-null  float64
#  2   Average Contrast            16800 non-null  float64
#  3   Average Spatial Noise       16800 non-null  float64
#  4   Average Temporal Noise      16800 non-null  float64
#  5   Average Colorfulness Index  16800 non-null  float64
#  6   Average Color Banding       16800 non-null  float64
#  7   Average Blockiness          16800 non-null  float64
#  8   Average Sharpness           16800 non-null  float64
#  9   Average Blur                16800 non-null  float64
#  10  Quality Score               16800 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 1.4+ MB

# %%
merged_df.to_csv("scores_features.csv")
